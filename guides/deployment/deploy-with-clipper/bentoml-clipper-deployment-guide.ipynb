# %% [markdown]
# # BentoML Clipper Deployment Guide
#
# Clipper(http://clipper.ai/) is a low-latency prediction serving system for machine learning.
#
# It provides a powerful way to orchastrate ML model containers and supports features such as [micro batching](https://www.usenix.org/system/files/conference/nsdi17/nsdi17-crankshaw.pdf) which is critical for building low latency online model serving systems.
#
# BentoML makes it easier to build custom containers that can be deployed to Clipper, users can easily add Clipper specify API handlers to their prediction service created with BentoML, and deploy them into clipper cluster. In this guide, we will demonstrate how to deploy a scikit-learn model to clipper, using BentoML.

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
# !pip install bentoml clipper_admin
# !pip install pandas sklearn

# %% [markdown]
# Train a Iris classifier model:

# %%
from sklearn import svm
from sklearn import datasets

clf = svm.SVC()
iris = datasets.load_iris()
X, y = iris.data, iris.target
clf.fit(X, y)
# Out:
# /Users/chaoyuyang/anaconda3/envs/dev/lib/python2.7/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)

# %% [markdown]
# BentoML provides handler types that are specific for use with Clipper, including ```ClipperBytesHandler```, ```ClipperIntsHandler```, ```ClipperFloatsHandler```, ```ClipperDoublesHandler```, ```ClipperStringsHandler``` each corresponding to one input type that clipper support.
#
# Other than using Clipper specific handler, the rest are the same as defining a regular BentoService class:

# %%
# %%writefile iris_classifier.py
from bentoml import BentoService, api, env, artifacts
from bentoml.artifact import PickleArtifact
from bentoml.handlers import DataframeHandler, ClipperFloatsHandler

@artifacts([PickleArtifact('model')])
@env(pip_dependencies=["scikit-learn"])
class IrisClassifier(BentoService):

    @api(DataframeHandler)
    def predict(self, df):
        return self.artifacts.model.predict(df)
    
    @api(ClipperFloatsHandler)
    def predict_clipper(self, inputs):
        return self.artifacts.model.predict(inputs)
# Out:
# Overwriting iris_classifier.py

# %%
# 1) import the custom BentoService defined above
from iris_classifier import IrisClassifier

# 2) `pack` it with required artifacts
svc = IrisClassifier()
svc.pack('model', clf)

# 3) save packed BentoService as archive
saved_path = svc.save()
# Out:
# [2019-11-13 15:41:13,233] WARNING - BentoML local changes detected - Local BentoML repository including all code changes will be bundled together with the BentoService archive. When used with docker, the base docker image will be default to same version as last PyPI release at version: 0.4.9. You can also force bentoml to use a specific version for deploying your BentoService archive, by setting the config 'core/bentoml_deploy_version' to a pinned version or your custom BentoML on github, e.g.:'bentoml_deploy_version = git+https://github.com/{username}/bentoml.git@{branch}'
# [2019-11-13 15:41:21,620] WARNING - BentoML local changes detected - Local BentoML repository including all code changes will be bundled together with the BentoService archive. When used with docker, the base docker image will be default to same version as last PyPI release at version: 0.4.9. You can also force bentoml to use a specific version for deploying your BentoService archive, by setting the config 'core/bentoml_deploy_version' to a pinned version or your custom BentoML on github, e.g.:'bentoml_deploy_version = git+https://github.com/{username}/bentoml.git@{branch}'
# running sdist
# running egg_info
# writing requirements to BentoML.egg-info/requires.txt
# writing BentoML.egg-info/PKG-INFO
# writing top-level names to BentoML.egg-info/top_level.txt
# writing dependency_links to BentoML.egg-info/dependency_links.txt
# writing entry points to BentoML.egg-info/entry_points.txt
# reading manifest file 'BentoML.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# no previously-included directories found matching 'examples'
# no previously-included directories found matching 'tests'
# no previously-included directories found matching 'docs'
# warning: no previously-included files matching '*~' found anywhere in distribution
# warning: no previously-included files matching '*.pyo' found anywhere in distribution
# warning: no previously-included files matching '.git' found anywhere in distribution
# warning: no previously-included files matching '.ipynb_checkpoints' found anywhere in distribution
# warning: no previously-included files matching '__pycache__' found anywhere in distribution
# writing manifest file 'BentoML.egg-info/SOURCES.txt'
# running check
# creating BentoML-0.4.9+7.g429b9ec.dirty
# creating BentoML-0.4.9+7.g429b9ec.dirty/BentoML.egg-info
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/archive
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/artifact
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/cli
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/clipper
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/configuration
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/deployment
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/deployment/sagemaker
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/deployment/serverless
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/handlers
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/migrations
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/migrations/versions
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/proto
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/repository
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/server
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/server/static
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/utils
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/utils/validator
# creating BentoML-0.4.9+7.g429b9ec.dirty/bentoml/yatai
# copying files to BentoML-0.4.9+7.g429b9ec.dirty...
# copying LICENSE -> BentoML-0.4.9+7.g429b9ec.dirty
# copying MANIFEST.in -> BentoML-0.4.9+7.g429b9ec.dirty
# copying README.md -> BentoML-0.4.9+7.g429b9ec.dirty
# copying setup.cfg -> BentoML-0.4.9+7.g429b9ec.dirty
# copying setup.py -> BentoML-0.4.9+7.g429b9ec.dirty
# copying versioneer.py -> BentoML-0.4.9+7.g429b9ec.dirty
# copying BentoML.egg-info/PKG-INFO -> BentoML-0.4.9+7.g429b9ec.dirty/BentoML.egg-info
# copying BentoML.egg-info/SOURCES.txt -> BentoML-0.4.9+7.g429b9ec.dirty/BentoML.egg-info
# copying BentoML.egg-info/dependency_links.txt -> BentoML-0.4.9+7.g429b9ec.dirty/BentoML.egg-info
# copying BentoML.egg-info/entry_points.txt -> BentoML-0.4.9+7.g429b9ec.dirty/BentoML.egg-info
# copying BentoML.egg-info/requires.txt -> BentoML-0.4.9+7.g429b9ec.dirty/BentoML.egg-info
# copying BentoML.egg-info/top_level.txt -> BentoML-0.4.9+7.g429b9ec.dirty/BentoML.egg-info
# copying bentoml/__init__.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml
# copying bentoml/_version.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml
# copying bentoml/alembic.ini -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml
# copying bentoml/db.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml
# copying bentoml/exceptions.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml
# copying bentoml/service.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml
# copying bentoml/service_env.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml
# copying bentoml/archive/__init__.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/archive
# copying bentoml/archive/archiver.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/archive
# copying bentoml/archive/config.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/archive
# copying bentoml/archive/loader.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/archive
# copying bentoml/archive/py_module_utils.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/archive
# copying bentoml/archive/templates.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/archive
# copying bentoml/archive/utils.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/archive
# copying bentoml/artifact/__init__.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/artifact
# copying bentoml/artifact/artifact.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/artifact
# copying bentoml/artifact/fastai_model_artifact.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/artifact
# copying bentoml/artifact/h2o_model_artifact.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/artifact
# copying bentoml/artifact/keras_model_artifact.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/artifact
# copying bentoml/artifact/pickle_artifact.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/artifact
# copying bentoml/artifact/pytorch_model_artifact.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/artifact
# copying bentoml/artifact/sklearn_model_artifact.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/artifact
# copying bentoml/artifact/text_file_artifact.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/artifact
# copying bentoml/artifact/tf_savedmodel_artifact.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/artifact
# copying bentoml/artifact/xgboost_model_artifact.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/artifact
# copying bentoml/cli/__init__.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/cli
# copying bentoml/cli/click_utils.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/cli
# copying bentoml/cli/config.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/cli
# copying bentoml/cli/deployment.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/cli
# copying bentoml/cli/utils.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/cli
# copying bentoml/clipper/__init__.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/clipper
# copying bentoml/configuration/__init__.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/configuration
# copying bentoml/configuration/configparser.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/configuration
# copying bentoml/configuration/default_bentoml.cfg -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/configuration
# copying bentoml/deployment/__init__.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/deployment
# copying bentoml/deployment/operator.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/deployment
# copying bentoml/deployment/store.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/deployment
# copying bentoml/deployment/utils.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/deployment
# copying bentoml/deployment/sagemaker/__init__.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/deployment/sagemaker
# copying bentoml/deployment/sagemaker/templates.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/deployment/sagemaker
# copying bentoml/deployment/serverless/__init__.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/deployment/serverless
# copying bentoml/deployment/serverless/aws_lambda.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/deployment/serverless
# copying bentoml/deployment/serverless/gcp_function.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/deployment/serverless
# copying bentoml/deployment/serverless/serverless_utils.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/deployment/serverless
# copying bentoml/handlers/__init__.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/handlers
# copying bentoml/handlers/base_handlers.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/handlers
# copying bentoml/handlers/clipper_handler.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/handlers
# copying bentoml/handlers/dataframe_handler.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/handlers
# copying bentoml/handlers/fastai_image_handler.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/handlers
# copying bentoml/handlers/image_handler.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/handlers
# copying bentoml/handlers/json_handler.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/handlers
# copying bentoml/handlers/pytorch_tensor_handler.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/handlers
# copying bentoml/handlers/tensorflow_tensor_handler.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/handlers
# copying bentoml/migrations/README -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/migrations
# copying bentoml/migrations/env.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/migrations
# copying bentoml/migrations/script.py.mako -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/migrations
# copying bentoml/migrations/versions/a6b00ae45279_add_last_updated_at_for_deployments.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/migrations/versions
# copying bentoml/proto/__init__.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/proto
# copying bentoml/proto/deployment_pb2.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/proto
# copying bentoml/proto/repository_pb2.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/proto
# copying bentoml/proto/status_pb2.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/proto
# copying bentoml/proto/yatai_service_pb2.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/proto
# copying bentoml/proto/yatai_service_pb2_grpc.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/proto
# copying bentoml/repository/__init__.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/repository
# copying bentoml/repository/metadata_store.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/repository
# copying bentoml/server/__init__.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/server
# copying bentoml/server/bento_api_server.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/server
# copying bentoml/server/bento_sagemaker_server.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/server
# copying bentoml/server/gunicorn_server.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/server
# copying bentoml/server/metrics.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/server
# copying bentoml/server/utils.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/server
# copying bentoml/server/static/swagger-ui-bundle.js -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/server/static
# copying bentoml/server/static/swagger-ui.css -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/server/static
# copying bentoml/utils/__init__.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/utils
# copying bentoml/utils/cloudpickle.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/utils
# copying bentoml/utils/hybirdmethod.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/utils
# copying bentoml/utils/log.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/utils
# copying bentoml/utils/s3.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/utils
# copying bentoml/utils/tempdir.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/utils
# copying bentoml/utils/usage_stats.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/utils
# copying bentoml/utils/whichcraft.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/utils
# copying bentoml/utils/validator/__init__.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/utils/validator
# copying bentoml/yatai/__init__.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/yatai
# copying bentoml/yatai/deployment_utils.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/yatai
# copying bentoml/yatai/python_api.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/yatai
# copying bentoml/yatai/status.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/yatai
# copying bentoml/yatai/yatai_service_impl.py -> BentoML-0.4.9+7.g429b9ec.dirty/bentoml/yatai
# Writing BentoML-0.4.9+7.g429b9ec.dirty/setup.cfg
# UPDATING BentoML-0.4.9+7.g429b9ec.dirty/bentoml/_version.py
# set BentoML-0.4.9+7.g429b9ec.dirty/bentoml/_version.py to '0.4.9+7.g429b9ec.dirty'
# Creating tar archive
# removing 'BentoML-0.4.9+7.g429b9ec.dirty' (and everything under it)
# [2019-11-13 15:41:24,087] INFO - BentoService bundle 'IrisClassifier:20191113154121_E7D3CE' created at: /private/var/folders/ns/vc9qhmqx5dx_9fws7d869lqh0000gn/T/bentoml-temp-B5oghW
# [2019-11-13 15:41:24,090] WARNING - BentoML local changes detected - Local BentoML repository including all code changes will be bundled together with the BentoService archive. When used with docker, the base docker image will be default to same version as last PyPI release at version: 0.4.9. You can also force bentoml to use a specific version for deploying your BentoService archive, by setting the config 'core/bentoml_deploy_version' to a pinned version or your custom BentoML on github, e.g.:'bentoml_deploy_version = git+https://github.com/{username}/bentoml.git@{branch}'
# [2019-11-13 15:41:24,115] WARNING - BentoArchive version mismatch: loading archive bundled in version 0.4.9,  but loading from version 0.4.9+7.g429b9ec.dirty
# [2019-11-13 15:41:24,395] INFO - BentoService bundle 'IrisClassifier:20191113154121_E7D3CE' created at: /Users/chaoyuyang/bentoml/repository/IrisClassifier/20191113154121_E7D3CE

# %%
# Test the clipper handler directly with list of floats as input
svc.predict_clipper([X[0]])
# Out:
# array([0])

# %% [markdown]
# ### Deploy BentoService bundle to Clipper cluster
#
# The sample code below assumes you have docker setup and starts a local Clipper cluster using Docker.

# %%
from clipper_admin import ClipperConnection, DockerContainerManager
cl = ClipperConnection(DockerContainerManager())
cl.start_clipper()
# Out:
# 19-11-13:15:43:33 INFO     [docker_container_manager.py:184] [default-cluster] Starting managed Redis instance in Docker
# 19-11-13:15:43:37 INFO     [docker_container_manager.py:276] [default-cluster] Metric Configuration Saved at /private/var/folders/ns/vc9qhmqx5dx_9fws7d869lqh0000gn/T/tmp_V3qv1.yml
# 19-11-13:15:43:38 INFO     [clipper_admin.py:162] [default-cluster] Clipper is running

# %%
# We will register it to deploy our BentoService
cl.register_application('bentoml-test', 'floats', 'default_pred', 100000)
# Out:
# 19-11-13:15:43:58 INFO     [clipper_admin.py:236] [default-cluster] Application bentoml-test was successfully registered

# %% [markdown]
# Now you can deploy the saved BentoService bundle using this clipper connection and BentoML's  ```bentoml.clipper.deploy_bentoml``` API, which will first build a clipper model docker image containing your BentoService and then deploy it to the cluster:

# %%
from bentoml.clipper import deploy_bentoml

clipper_model_name, clipper_model_version = deploy_bentoml(cl, saved_path, "predict_clipper")
# Out:
# [2019-11-13 15:45:49,422] WARNING - BentoML local changes detected - Local BentoML repository including all code changes will be bundled together with the BentoService archive. When used with docker, the base docker image will be default to same version as last PyPI release at version: 0.4.9. You can also force bentoml to use a specific version for deploying your BentoService archive, by setting the config 'core/bentoml_deploy_version' to a pinned version or your custom BentoML on github, e.g.:'bentoml_deploy_version = git+https://github.com/{username}/bentoml.git@{branch}'
# [2019-11-13 15:45:49,444] WARNING - BentoArchive version mismatch: loading archive bundled in version 0.4.9,  but loading from version 0.4.9+7.g429b9ec.dirty
# [2019-11-13 15:45:49,772] INFO - Step 1/10 : FROM clipper/python-closure-container:0.4.1
# [2019-11-13 15:45:49,775] INFO -
#
# [2019-11-13 15:45:49,777] INFO -  ---> e9b89c285ef8
#
# [2019-11-13 15:45:49,780] INFO - Step 2/10 : COPY . /container
# [2019-11-13 15:45:49,782] INFO -
#
# [2019-11-13 15:45:50,162] INFO -  ---> f402705036ff
#
# [2019-11-13 15:45:50,164] INFO - Step 3/10 : WORKDIR /container
# [2019-11-13 15:45:50,166] INFO -
#
# [2019-11-13 15:45:50,265] INFO -  ---> Running in 2de084367c25
#
# [2019-11-13 15:45:50,590] INFO -  ---> ba98224ca802
#
# [2019-11-13 15:45:50,592] INFO - Step 4/10 : RUN pip install --upgrade numpy && pip install -r /container/bento/requirements.txt
# [2019-11-13 15:45:50,595] INFO -
#
# [2019-11-13 15:45:50,756] INFO -  ---> Running in 400dba1836e1
#
# [2019-11-13 15:45:51,556] INFO - DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7.
#
# [2019-11-13 15:45:52,192] INFO - Collecting numpy
#
# [2019-11-13 15:45:52,748] INFO -   Downloading https://files.pythonhosted.org/packages/d7/b1/3367ea1f372957f97a6752ec725b87886e12af1415216feec9067e31df70/numpy-1.16.5-cp27-cp27mu-manylinux1_x86_64.whl (17.0MB)
#
# [2019-11-13 15:45:55,937] INFO - Installing collected packages: numpy
#
# [2019-11-13 15:45:55,939] INFO -   Found existing installation: numpy 1.14.6
#
# [2019-11-13 15:45:56,019] INFO -     Uninstalling numpy-1.14.6:
#
# [2019-11-13 15:45:56,582] INFO -       Successfully uninstalled numpy-1.14.6
#
# [2019-11-13 15:45:57,922] INFO - Successfully installed numpy-1.16.5
#
# [2019-11-13 15:45:58,098] INFO - WARNING: You are using pip version 19.1.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
#
# [2019-11-13 15:45:58,343] INFO - DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7.
#
# [2019-11-13 15:45:58,387] INFO - Collecting bentoml==0.4.9 (from -r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:45:58,908] INFO -   Downloading https://files.pythonhosted.org/packages/ca/00/32657d4f6e75177bfbf0f01a59a70054122b8aae28cfc669f726cae7a425/BentoML-0.4.9.tar.gz (440kB)
#
# [2019-11-13 15:45:59,436] INFO - Collecting scikit-learn (from -r /container/bento/requirements.txt (line 2))
#
# [2019-11-13 15:45:59,657] INFO -   Downloading https://files.pythonhosted.org/packages/31/9f/042db462417451e81035c3d43b722e88450c628a33dfda69777a801b0d40/scikit_learn-0.20.4-cp27-cp27mu-manylinux1_x86_64.whl (5.5MB)
#
# [2019-11-13 15:46:00,542] INFO - Collecting ruamel.yaml>=0.15.0 (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:01,328] INFO -   Downloading https://files.pythonhosted.org/packages/fa/90/ecff85a2e9c497e2fa7142496e10233556b5137db5bd46f3f3b006935ca8/ruamel.yaml-0.16.5-py2.py3-none-any.whl (123kB)
#
# [2019-11-13 15:46:01,372] INFO - Requirement already satisfied: numpy in /usr/local/lib/python2.7/site-packages (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (1.16.5)
#
# [2019-11-13 15:46:01,374] INFO - Requirement already satisfied: flask in /usr/local/lib/python2.7/site-packages (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (0.12.2)
#
# [2019-11-13 15:46:01,395] INFO - Collecting gunicorn (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:01,459] INFO -   Downloading https://files.pythonhosted.org/packages/8c/da/b8dd8deb741bff556db53902d4706774c8e1e67265f69528c14c003644e6/gunicorn-19.9.0-py2.py3-none-any.whl (112kB)
#
# [2019-11-13 15:46:01,494] INFO - Requirement already satisfied: six in /usr/local/lib/python2.7/site-packages (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (1.12.0)
#
# [2019-11-13 15:46:01,496] INFO - Requirement already satisfied: click>=7.0 in /usr/local/lib/python2.7/site-packages (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (7.0)
#
# [2019-11-13 15:46:01,510] INFO - Collecting pandas (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:01,824] INFO -   Downloading https://files.pythonhosted.org/packages/db/83/7d4008ffc2988066ff37f6a0bb6d7b60822367dcb36ba5e39aa7801fda54/pandas-0.24.2-cp27-cp27mu-manylinux1_x86_64.whl (10.1MB)
#
# [2019-11-13 15:46:03,599] INFO - Collecting dill (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:03,643] INFO -   Downloading https://files.pythonhosted.org/packages/c7/11/345f3173809cea7f1a193bfbf02403fff250a3360e0e118a1630985e547d/dill-0.3.1.1.tar.gz (151kB)
#
# [2019-11-13 15:46:03,885] INFO - Requirement already satisfied: prometheus_client in /usr/local/lib/python2.7/site-packages (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (0.1.1)
#
# [2019-11-13 15:46:03,905] INFO - Collecting python-json-logger (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:03,949] INFO -   Downloading https://files.pythonhosted.org/packages/80/9d/1c3393a6067716e04e6fcef95104c8426d262b4adaf18d7aa2470eab028d/python-json-logger-0.1.11.tar.gz
#
# [2019-11-13 15:46:04,198] INFO - Collecting boto3 (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:04,587] INFO -   Downloading https://files.pythonhosted.org/packages/06/04/257af61ae66188fe4cc7fce0a1b1ad4baf675d9e47924c83d723904ce159/boto3-1.10.17-py2.py3-none-any.whl (128kB)
#
# [2019-11-13 15:46:04,643] INFO - Collecting pathlib2 (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:04,686] INFO -   Downloading https://files.pythonhosted.org/packages/e9/45/9c82d3666af4ef9f221cbb954e1d77ddbb513faf552aea6df5f37f1a4859/pathlib2-2.3.5-py2.py3-none-any.whl
#
# [2019-11-13 15:46:04,711] INFO - Requirement already satisfied: requests in /usr/local/lib/python2.7/site-packages (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (2.22.0)
#
# [2019-11-13 15:46:04,745] INFO - Collecting packaging (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:04,810] INFO -   Downloading https://files.pythonhosted.org/packages/cf/94/9672c2d4b126e74c4496c6b3c58a8b51d6419267be9e70660ba23374c875/packaging-19.2-py2.py3-none-any.whl
#
# [2019-11-13 15:46:04,837] INFO - Requirement already satisfied: docker in /usr/local/lib/python2.7/site-packages (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (4.0.1)
#
# [2019-11-13 15:46:04,875] INFO - Collecting configparser (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:04,915] INFO -   Downloading https://files.pythonhosted.org/packages/7a/2a/95ed0501cf5d8709490b1d3a3f9b5cf340da6c433f896bbe9ce08dbe6785/configparser-4.0.2-py2.py3-none-any.whl
#
# [2019-11-13 15:46:04,951] INFO - Collecting sqlalchemy>=1.3.0 (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:05,044] INFO -   Downloading https://files.pythonhosted.org/packages/34/5c/0e1d7ad0ca52544bb12f9cb8d5cc454af45821c92160ffedd38db0a317f6/SQLAlchemy-1.3.11.tar.gz (6.0MB)
#
# [2019-11-13 15:46:06,951] INFO - Collecting protobuf>=3.6.0 (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:07,098] INFO -   Downloading https://files.pythonhosted.org/packages/c5/49/ffa7ab9c52ec56b535cffec3bc844254c073888e6d4aeee464671ac97480/protobuf-3.10.0-cp27-cp27mu-manylinux1_x86_64.whl (1.3MB)
# [2019-11-13 15:46:07,324] INFO - Collecting grpcio (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:08,219] INFO -   Downloading https://files.pythonhosted.org/packages/0c/47/35cc9f6fd43f8e5ed74fcc6dd8a0cb2e89c118dd3ef7a8ff25e65bf0909f/grpcio-1.25.0-cp27-cp27mu-manylinux2010_x86_64.whl (2.4MB)
#
# [2019-11-13 15:46:08,572] INFO - Collecting cerberus (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:08,605] INFO -   Downloading https://files.pythonhosted.org/packages/90/a7/71c6ed2d46a81065e68c007ac63378b96fa54c7bb614d653c68232f9c50c/Cerberus-1.3.2.tar.gz (52kB)
#
# [2019-11-13 15:46:08,823] INFO - Collecting tabulate (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:08,858] INFO -   Downloading https://files.pythonhosted.org/packages/66/d4/977fdd5186b7cdbb7c43a7aac7c5e4e0337a84cb802e154616f3cfc84563/tabulate-0.8.5.tar.gz (45kB)
#
# [2019-11-13 15:46:09,079] INFO - Collecting humanfriendly (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:09,164] INFO -   Downloading https://files.pythonhosted.org/packages/90/df/88bff450f333114680698dc4aac7506ff7cab164b794461906de31998665/humanfriendly-4.18-py2.py3-none-any.whl (73kB)
#
# [2019-11-13 15:46:09,215] INFO - Collecting alembic (from bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:09,291] INFO -   Downloading https://files.pythonhosted.org/packages/84/64/493c45119dce700a4b9eeecc436ef9e8835ab67bae6414f040cdc7b58f4b/alembic-1.3.1.tar.gz (1.1MB)
#
# [2019-11-13 15:46:09,836] INFO - Collecting scipy>=0.13.3 (from scikit-learn->-r /container/bento/requirements.txt (line 2))
#
# [2019-11-13 15:46:10,120] INFO -   Downloading https://files.pythonhosted.org/packages/1d/f6/7c16d60aeb3694e5611976cb4f1eaf1c6b7f1e7c55771d691013405a02ea/scipy-1.2.2-cp27-cp27mu-manylinux1_x86_64.whl (24.8MB)
#
# [2019-11-13 15:46:14,372] INFO - Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.8" (from ruamel.yaml>=0.15.0->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:14,418] INFO -   Downloading https://files.pythonhosted.org/packages/c2/90/d919a3c81e308fe9665c1bab6b73ada9d183eed0a5dcf9c7b47419a54628/ruamel.yaml.clib-0.2.0-cp27-cp27mu-manylinux1_x86_64.whl (493kB)
#
# [2019-11-13 15:46:14,492] INFO - Collecting ruamel.ordereddict; platform_python_implementation == "CPython" and python_version <= "2.7" (from ruamel.yaml>=0.15.0->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:14,530] INFO -   Downloading https://files.pythonhosted.org/packages/8c/d6/4971e55c60b972160b911368fa4cd756d68739b6616b0cb57d09d8a6ee18/ruamel.ordereddict-0.4.14-cp27-cp27mu-manylinux1_x86_64.whl (93kB)
#
# [2019-11-13 15:46:14,554] INFO - Requirement already satisfied: Jinja2>=2.4 in /usr/local/lib/python2.7/site-packages (from flask->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (2.10.1)
#
# [2019-11-13 15:46:14,559] INFO - Requirement already satisfied: Werkzeug>=0.7 in /usr/local/lib/python2.7/site-packages (from flask->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (0.15.4)
#
# [2019-11-13 15:46:14,569] INFO - Requirement already satisfied: itsdangerous>=0.21 in /usr/local/lib/python2.7/site-packages (from flask->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (1.1.0)
#
# [2019-11-13 15:46:14,573] INFO - Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python2.7/site-packages (from pandas->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (2.8.0)
#
# [2019-11-13 15:46:14,589] INFO - Collecting pytz>=2011k (from pandas->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:14,857] INFO -   Downloading https://files.pythonhosted.org/packages/e7/f9/f0b53f88060247251bf481fa6ea62cd0d25bf1b11a87888e53ce5b7c8ad2/pytz-2019.3-py2.py3-none-any.whl (509kB)
#
# [2019-11-13 15:46:15,026] INFO - Collecting s3transfer<0.3.0,>=0.2.0 (from boto3->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:15,064] INFO -   Downloading https://files.pythonhosted.org/packages/16/8a/1fc3dba0c4923c2a76e1ff0d52b305c44606da63f718d14d3231e21c51b0/s3transfer-0.2.1-py2.py3-none-any.whl (70kB)
#
# [2019-11-13 15:46:15,107] INFO - Collecting botocore<1.14.0,>=1.13.17 (from boto3->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:15,848] INFO -   Downloading https://files.pythonhosted.org/packages/d0/d8/67eec2958748b0084370a6ffb1cdb5c658400fbc7da51915303607ae7af3/botocore-1.13.17-py2.py3-none-any.whl (5.4MB)
#
# [2019-11-13 15:46:17,338] INFO - Collecting jmespath<1.0.0,>=0.7.1 (from boto3->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:17,377] INFO -   Downloading https://files.pythonhosted.org/packages/83/94/7179c3832a6d45b266ddb2aac329e101367fbdb11f425f13771d27f225bb/jmespath-0.9.4-py2.py3-none-any.whl
#
# [2019-11-13 15:46:17,408] INFO - Collecting scandir; python_version < "3.5" (from pathlib2->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:17,461] INFO -   Downloading https://files.pythonhosted.org/packages/df/f5/9c052db7bd54d0cbf1bc0bb6554362bba1012d03e5888950a4f5c5dadc4e/scandir-1.10.0.tar.gz
#
# [2019-11-13 15:46:17,713] INFO - Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python2.7/site-packages (from requests->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (3.0.4)
#
# [2019-11-13 15:46:17,716] INFO - Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python2.7/site-packages (from requests->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (2.8)
#
# [2019-11-13 15:46:17,721] INFO - Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python2.7/site-packages (from requests->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (1.25.3)
#
# [2019-11-13 15:46:17,738] INFO - Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python2.7/site-packages (from requests->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (2019.3.9)
#
# [2019-11-13 15:46:17,755] INFO - Collecting pyparsing>=2.0.2 (from packaging->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:17,882] INFO -   Downloading https://files.pythonhosted.org/packages/c0/0c/fc2e007d9a992d997f04a80125b0f183da7fb554f1de701bbb70a8e7d479/pyparsing-2.4.5-py2.py3-none-any.whl (67kB)
#
# [2019-11-13 15:46:17,905] INFO - Requirement already satisfied: ipaddress>=1.0.16; python_version < "3.3" in /usr/local/lib/python2.7/site-packages (from docker->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (1.0.22)
#
# [2019-11-13 15:46:17,908] INFO - Requirement already satisfied: websocket-client>=0.32.0 in /usr/local/lib/python2.7/site-packages (from docker->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (0.56.0)
#
# [2019-11-13 15:46:17,913] INFO - Requirement already satisfied: backports.ssl-match-hostname>=3.5; python_version < "3.5" in /usr/local/lib/python2.7/site-packages (from docker->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (3.7.0.1)
#
# [2019-11-13 15:46:17,915] INFO - Requirement already satisfied: setuptools in /usr/local/lib/python2.7/site-packages (from protobuf>=3.6.0->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (39.1.0)
#
# [2019-11-13 15:46:17,934] INFO - Collecting futures>=2.2.0; python_version < "3.2" (from grpcio->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:17,985] INFO -   Downloading https://files.pythonhosted.org/packages/d8/a6/f46ae3f1da0cd4361c344888f59ec2f5785e69c872e175a748ef6071cdb5/futures-3.3.0-py2-none-any.whl
#
# [2019-11-13 15:46:18,008] INFO - Requirement already satisfied: enum34>=1.0.4; python_version < "3.4" in /usr/local/lib/python2.7/site-packages (from grpcio->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (1.1.6)
#
# [2019-11-13 15:46:18,024] INFO - Collecting monotonic; python_version == "2.6" or python_version == "2.7" or python_version == "3.0" or python_version == "3.1" or python_version == "3.2" (from humanfriendly->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
# [2019-11-13 15:46:18,058] INFO -   Downloading https://files.pythonhosted.org/packages/ac/aa/063eca6a416f397bd99552c534c6d11d57f58f2e94c14780f3bbf818c4cf/monotonic-1.5-py2.py3-none-any.whl
#
# [2019-11-13 15:46:18,099] INFO - Collecting Mako (from alembic->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:18,148] INFO -   Downloading https://files.pythonhosted.org/packages/b0/3c/8dcd6883d009f7cae0f3157fb53e9afb05a0d3d33b3db1268ec2e6f4a56b/Mako-1.1.0.tar.gz (463kB)
#
# [2019-11-13 15:46:18,538] INFO - Collecting python-editor>=0.3 (from alembic->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:18,570] INFO -   Downloading https://files.pythonhosted.org/packages/55/a0/3c0ba1c10f2ca381645dd46cb7afbb73fddc8de9f957e1f9e726a846eabc/python_editor-1.0.4-py2-none-any.whl
#
# [2019-11-13 15:46:18,592] INFO - Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python2.7/site-packages (from Jinja2>=2.4->flask->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1)) (1.1.1)
#
# [2019-11-13 15:46:18,608] INFO - Collecting docutils<0.16,>=0.10 (from botocore<1.14.0,>=1.13.17->boto3->bentoml==0.4.9->-r /container/bento/requirements.txt (line 1))
#
# [2019-11-13 15:46:18,658] INFO -   Downloading https://files.pythonhosted.org/packages/3a/dc/bf2b15d1fa15a6f7a9e77a61b74ecbbae7258558fcda8ffc9a6638a6b327/docutils-0.15.2-py2-none-any.whl (548kB)
#
# [2019-11-13 15:46:18,820] INFO - Building wheels for collected packages: bentoml, dill, python-json-logger, sqlalchemy, cerberus, tabulate, alembic, scandir, Mako
#
# [2019-11-13 15:46:18,821] INFO -   Building wheel for bentoml (setup.py): started
#
# [2019-11-13 15:46:19,361] INFO -   Building wheel for bentoml (setup.py): finished with status 'done'
#
# [2019-11-13 15:46:19,363] INFO -   Stored in directory: /root/.cache/pip/wheels/05/74/4a/a9a7ddf593fc4f186db580e201a320ce986c7e8d3b1c6aa474
#
# [2019-11-13 15:46:19,396] INFO -   Building wheel for dill (setup.py): started
#
# [2019-11-13 15:46:19,645] INFO -   Building wheel for dill (setup.py): finished with status 'done'
#
# [2019-11-13 15:46:19,647] INFO -   Stored in directory: /root/.cache/pip/wheels/59/b1/91/f02e76c732915c4015ab4010f3015469866c1eb9b14058d8e7
#
# [2019-11-13 15:46:19,660] INFO -   Building wheel for python-json-logger (setup.py): started
#
# [2019-11-13 15:46:19,878] INFO -   Building wheel for python-json-logger (setup.py): finished with status 'done'
#
# [2019-11-13 15:46:19,880] INFO -   Stored in directory: /root/.cache/pip/wheels/97/f7/a1/752e22bb30c1cfe38194ea0070a5c66e76ef4d06ad0c7dc401
#
# [2019-11-13 15:46:19,883] INFO -   Building wheel for sqlalchemy (setup.py): started
#
# [2019-11-13 15:46:21,253] INFO -   Building wheel for sqlalchemy (setup.py): finished with status 'done'
#
# [2019-11-13 15:46:21,255] INFO -   Stored in directory: /root/.cache/pip/wheels/a3/67/7d/6c41104a1a08ff1a25e260d3edec3ac19203141d1aaa2f0975
#
# [2019-11-13 15:46:21,360] INFO -   Building wheel for cerberus (setup.py): started
#
# [2019-11-13 15:46:21,592] INFO -   Building wheel for cerberus (setup.py): finished with status 'done'
#
# [2019-11-13 15:46:21,594] INFO -   Stored in directory: /root/.cache/pip/wheels/e9/38/1f/f2cc84182676f3ae7134b9b2d744f9c235b24d2ddc8f7fe465
#
# [2019-11-13 15:46:21,602] INFO -   Building wheel for tabulate (setup.py): started
#
# [2019-11-13 15:46:21,833] INFO -   Building wheel for tabulate (setup.py): finished with status 'done'
#
# [2019-11-13 15:46:21,835] INFO -   Stored in directory: /root/.cache/pip/wheels/e1/41/5e/e201f95d90fc84f93aa629b6638adacda680fe63aac47174ab
#
# [2019-11-13 15:46:21,840] INFO -   Building wheel for alembic (setup.py): started
#
# [2019-11-13 15:46:22,151] INFO -   Building wheel for alembic (setup.py): finished with status 'done'
#
# [2019-11-13 15:46:22,153] INFO -   Stored in directory: /root/.cache/pip/wheels/b2/d4/19/5ab879d30af7cbc79e6dcc1d421795b1aa9d78f455b0412ef7
#
# [2019-11-13 15:46:22,187] INFO -   Building wheel for scandir (setup.py): started
#
# [2019-11-13 15:46:22,714] INFO -   Building wheel for scandir (setup.py): finished with status 'done'
#
# [2019-11-13 15:46:22,716] INFO -   Stored in directory: /root/.cache/pip/wheels/91/95/75/19c98a91239878abbc7c59970abd3b4e0438a7dd5b61778335
#
# [2019-11-13 15:46:22,721] INFO -   Building wheel for Mako (setup.py): started
#
# [2019-11-13 15:46:22,987] INFO -   Building wheel for Mako (setup.py): finished with status 'done'
#
# [2019-11-13 15:46:22,989] INFO -   Stored in directory: /root/.cache/pip/wheels/98/32/7b/a291926643fc1d1e02593e0d9e247c5a866a366b8343b7aa27
#
# [2019-11-13 15:46:23,004] INFO - Successfully built bentoml dill python-json-logger sqlalchemy cerberus tabulate alembic scandir Mako
#
# [2019-11-13 15:46:23,292] INFO - Installing collected packages: ruamel.yaml.clib, ruamel.ordereddict, ruamel.yaml, gunicorn, pytz, pandas, dill, python-json-logger, futures, docutils, jmespath, botocore, s3transfer, boto3, scandir, pathlib2, pyparsing, packaging, configparser, sqlalchemy, protobuf, grpcio, cerberus, tabulate, monotonic, humanfriendly, Mako, python-editor, alembic, bentoml, scipy, scikit-learn
#
# [2019-11-13 15:46:30,776] INFO - Successfully installed Mako-1.1.0 alembic-1.3.1 bentoml-0.4.9 boto3-1.10.17 botocore-1.13.17 cerberus-1.3.2 configparser-4.0.2 dill-0.3.1.1 docutils-0.15.2 futures-3.3.0 grpcio-1.25.0 gunicorn-19.9.0 humanfriendly-4.18 jmespath-0.9.4 monotonic-1.5 packaging-19.2 pandas-0.24.2 pathlib2-2.3.5 protobuf-3.10.0 pyparsing-2.4.5 python-editor-1.0.4 python-json-logger-0.1.11 pytz-2019.3 ruamel.ordereddict-0.4.14 ruamel.yaml-0.16.5 ruamel.yaml.clib-0.2.0 s3transfer-0.2.1 scandir-1.10.0 scikit-learn-0.20.4 scipy-1.2.2 sqlalchemy-1.3.11 tabulate-0.8.5
#
# [2019-11-13 15:46:31,089] INFO - WARNING: You are using pip version 19.1.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
#
# [2019-11-13 15:46:38,584] INFO -  ---> 4edbca462b8a
#
# [2019-11-13 15:46:38,586] INFO - Step 5/10 : RUN if [ -f /container/bento/bentoml_init.sh ]; then cd /container/bento && /bin/bash -c /container/bento/bentoml_init.sh; fi
# [2019-11-13 15:46:38,588] INFO -
#
# [2019-11-13 15:46:38,750] INFO -  ---> Running in bfcdf98a7814
#
# [2019-11-13 15:46:39,491] INFO - DEPRECATION: Python 2.7 will reach the end of its life on January 1st, 2020. Please upgrade your Python as Python 2.7 won't be maintained after that date. A future version of pip will drop support for Python 2.7.
#
# [2019-11-13 15:46:39,517] INFO - Processing ./bundled_pip_dependencies/BentoML-0.4.9+7.g429b9ec.dirty.tar.gz
#
# [2019-11-13 15:46:39,992] INFO - Requirement already satisfied, skipping upgrade: ruamel.yaml>=0.15.0 in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (0.16.5)
#
# [2019-11-13 15:46:40,012] INFO - Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (1.16.5)
#
# [2019-11-13 15:46:40,015] INFO - Requirement already satisfied, skipping upgrade: flask in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (0.12.2)
#
# [2019-11-13 15:46:40,023] INFO - Requirement already satisfied, skipping upgrade: gunicorn in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (19.9.0)
#
# [2019-11-13 15:46:40,031] INFO - Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (1.12.0)
#
# [2019-11-13 15:46:40,035] INFO - Requirement already satisfied, skipping upgrade: click>=7.0 in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (7.0)
#
# [2019-11-13 15:46:40,038] INFO - Requirement already satisfied, skipping upgrade: pandas in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (0.24.2)
#
# [2019-11-13 15:46:40,047] INFO - Requirement already satisfied, skipping upgrade: dill in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (0.3.1.1)
#
# [2019-11-13 15:46:40,053] INFO - Requirement already satisfied, skipping upgrade: prometheus_client in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (0.1.1)
# [2019-11-13 15:46:40,057] INFO - Requirement already satisfied, skipping upgrade: python-json-logger in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (0.1.11)
#
# [2019-11-13 15:46:40,063] INFO - Requirement already satisfied, skipping upgrade: boto3 in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (1.10.17)
#
# [2019-11-13 15:46:40,070] INFO - Requirement already satisfied, skipping upgrade: pathlib2 in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (2.3.5)
#
# [2019-11-13 15:46:40,077] INFO - Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (2.22.0)
#
# [2019-11-13 15:46:40,096] INFO - Requirement already satisfied, skipping upgrade: packaging in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (19.2)
#
# [2019-11-13 15:46:40,100] INFO - Requirement already satisfied, skipping upgrade: docker in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (4.0.1)
#
# [2019-11-13 15:46:40,120] INFO - Requirement already satisfied, skipping upgrade: configparser in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (4.0.2)
#
# [2019-11-13 15:46:40,133] INFO - Requirement already satisfied, skipping upgrade: sqlalchemy>=1.3.0 in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (1.3.11)
#
# [2019-11-13 15:46:40,152] INFO - Requirement already satisfied, skipping upgrade: protobuf>=3.6.0 in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (3.10.0)
#
# [2019-11-13 15:46:40,158] INFO - Requirement already satisfied, skipping upgrade: grpcio in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (1.25.0)
#
# [2019-11-13 15:46:40,170] INFO - Requirement already satisfied, skipping upgrade: cerberus in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (1.3.2)
#
# [2019-11-13 15:46:40,174] INFO - Requirement already satisfied, skipping upgrade: tabulate in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (0.8.5)
#
# [2019-11-13 15:46:40,184] INFO - Requirement already satisfied, skipping upgrade: humanfriendly in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (4.18)
#
# [2019-11-13 15:46:40,204] INFO - Requirement already satisfied, skipping upgrade: alembic in /usr/local/lib/python2.7/site-packages (from BentoML==0.4.9+7.g429b9ec.dirty) (1.3.1)
#
# [2019-11-13 15:46:40,215] INFO - Requirement already satisfied, skipping upgrade: ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.8" in /usr/local/lib/python2.7/site-packages (from ruamel.yaml>=0.15.0->BentoML==0.4.9+7.g429b9ec.dirty) (0.2.0)
#
# [2019-11-13 15:46:40,219] INFO - Requirement already satisfied, skipping upgrade: ruamel.ordereddict; platform_python_implementation == "CPython" and python_version <= "2.7" in /usr/local/lib/python2.7/site-packages (from ruamel.yaml>=0.15.0->BentoML==0.4.9+7.g429b9ec.dirty) (0.4.14)
#
# [2019-11-13 15:46:40,223] INFO - Requirement already satisfied, skipping upgrade: Jinja2>=2.4 in /usr/local/lib/python2.7/site-packages (from flask->BentoML==0.4.9+7.g429b9ec.dirty) (2.10.1)
#
# [2019-11-13 15:46:40,230] INFO - Requirement already satisfied, skipping upgrade: Werkzeug>=0.7 in /usr/local/lib/python2.7/site-packages (from flask->BentoML==0.4.9+7.g429b9ec.dirty) (0.15.4)
#
# [2019-11-13 15:46:40,246] INFO - Requirement already satisfied, skipping upgrade: itsdangerous>=0.21 in /usr/local/lib/python2.7/site-packages (from flask->BentoML==0.4.9+7.g429b9ec.dirty) (1.1.0)
#
# [2019-11-13 15:46:40,251] INFO - Requirement already satisfied, skipping upgrade: python-dateutil>=2.5.0 in /usr/local/lib/python2.7/site-packages (from pandas->BentoML==0.4.9+7.g429b9ec.dirty) (2.8.0)
#
# [2019-11-13 15:46:40,257] INFO - Requirement already satisfied, skipping upgrade: pytz>=2011k in /usr/local/lib/python2.7/site-packages (from pandas->BentoML==0.4.9+7.g429b9ec.dirty) (2019.3)
#
# [2019-11-13 15:46:40,262] INFO - Requirement already satisfied, skipping upgrade: s3transfer<0.3.0,>=0.2.0 in /usr/local/lib/python2.7/site-packages (from boto3->BentoML==0.4.9+7.g429b9ec.dirty) (0.2.1)
#
# [2019-11-13 15:46:40,273] INFO - Requirement already satisfied, skipping upgrade: botocore<1.14.0,>=1.13.17 in /usr/local/lib/python2.7/site-packages (from boto3->BentoML==0.4.9+7.g429b9ec.dirty) (1.13.17)
#
# [2019-11-13 15:46:40,296] INFO - Requirement already satisfied, skipping upgrade: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python2.7/site-packages (from boto3->BentoML==0.4.9+7.g429b9ec.dirty) (0.9.4)
#
# [2019-11-13 15:46:40,301] INFO - Requirement already satisfied, skipping upgrade: scandir; python_version < "3.5" in /usr/local/lib/python2.7/site-packages (from pathlib2->BentoML==0.4.9+7.g429b9ec.dirty) (1.10.0)
#
# [2019-11-13 15:46:40,304] INFO - Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python2.7/site-packages (from requests->BentoML==0.4.9+7.g429b9ec.dirty) (3.0.4)
#
# [2019-11-13 15:46:40,307] INFO - Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /usr/local/lib/python2.7/site-packages (from requests->BentoML==0.4.9+7.g429b9ec.dirty) (2.8)
#
# [2019-11-13 15:46:40,315] INFO - Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python2.7/site-packages (from requests->BentoML==0.4.9+7.g429b9ec.dirty) (1.25.3)
#
# [2019-11-13 15:46:40,335] INFO - Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python2.7/site-packages (from requests->BentoML==0.4.9+7.g429b9ec.dirty) (2019.3.9)
#
# [2019-11-13 15:46:40,337] INFO - Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/lib/python2.7/site-packages (from packaging->BentoML==0.4.9+7.g429b9ec.dirty) (2.4.5)
#
# [2019-11-13 15:46:40,340] INFO - Requirement already satisfied, skipping upgrade: ipaddress>=1.0.16; python_version < "3.3" in /usr/local/lib/python2.7/site-packages (from docker->BentoML==0.4.9+7.g429b9ec.dirty) (1.0.22)
#
# [2019-11-13 15:46:40,344] INFO - Requirement already satisfied, skipping upgrade: websocket-client>=0.32.0 in /usr/local/lib/python2.7/site-packages (from docker->BentoML==0.4.9+7.g429b9ec.dirty) (0.56.0)
#
# [2019-11-13 15:46:40,350] INFO - Requirement already satisfied, skipping upgrade: backports.ssl-match-hostname>=3.5; python_version < "3.5" in /usr/local/lib/python2.7/site-packages (from docker->BentoML==0.4.9+7.g429b9ec.dirty) (3.7.0.1)
#
# [2019-11-13 15:46:40,353] INFO - Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python2.7/site-packages (from protobuf>=3.6.0->BentoML==0.4.9+7.g429b9ec.dirty) (39.1.0)
#
# [2019-11-13 15:46:40,360] INFO - Requirement already satisfied, skipping upgrade: futures>=2.2.0; python_version < "3.2" in /usr/local/lib/python2.7/site-packages (from grpcio->BentoML==0.4.9+7.g429b9ec.dirty) (3.3.0)
#
# [2019-11-13 15:46:40,364] INFO - Requirement already satisfied, skipping upgrade: enum34>=1.0.4; python_version < "3.4" in /usr/local/lib/python2.7/site-packages (from grpcio->BentoML==0.4.9+7.g429b9ec.dirty) (1.1.6)
#
# [2019-11-13 15:46:40,370] INFO - Requirement already satisfied, skipping upgrade: monotonic; python_version == "2.6" or python_version == "2.7" or python_version == "3.0" or python_version == "3.1" or python_version == "3.2" in /usr/local/lib/python2.7/site-packages (from humanfriendly->BentoML==0.4.9+7.g429b9ec.dirty) (1.5)
#
# [2019-11-13 15:46:40,372] INFO - Requirement already satisfied, skipping upgrade: Mako in /usr/local/lib/python2.7/site-packages (from alembic->BentoML==0.4.9+7.g429b9ec.dirty) (1.1.0)
#
# [2019-11-13 15:46:40,377] INFO - Requirement already satisfied, skipping upgrade: python-editor>=0.3 in /usr/local/lib/python2.7/site-packages (from alembic->BentoML==0.4.9+7.g429b9ec.dirty) (1.0.4)
#
# [2019-11-13 15:46:40,380] INFO - Requirement already satisfied, skipping upgrade: MarkupSafe>=0.23 in /usr/local/lib/python2.7/site-packages (from Jinja2>=2.4->flask->BentoML==0.4.9+7.g429b9ec.dirty) (1.1.1)
# [2019-11-13 15:46:40,386] INFO - Requirement already satisfied, skipping upgrade: docutils<0.16,>=0.10 in /usr/local/lib/python2.7/site-packages (from botocore<1.14.0,>=1.13.17->boto3->BentoML==0.4.9+7.g429b9ec.dirty) (0.15.2)
#
# [2019-11-13 15:46:40,390] INFO - Building wheels for collected packages: BentoML
#
# [2019-11-13 15:46:40,393] INFO -   Building wheel for BentoML (setup.py): started
#
# [2019-11-13 15:46:40,930] INFO -   Building wheel for BentoML (setup.py): finished with status 'done'
#
# [2019-11-13 15:46:40,932] INFO -   Stored in directory: /root/.cache/pip/wheels/da/67/b3/c91c998ab11d6af43b3c59901aedd6356bc515fe408b4b5a96
#
# [2019-11-13 15:46:40,966] INFO - Successfully built BentoML
#
# [2019-11-13 15:46:41,295] INFO - Installing collected packages: BentoML
#
# [2019-11-13 15:46:41,296] INFO -   Found existing installation: BentoML 0.4.9
#
# [2019-11-13 15:46:41,316] INFO -     Uninstalling BentoML-0.4.9:
#
# [2019-11-13 15:46:41,358] INFO -       Successfully uninstalled BentoML-0.4.9
#
# [2019-11-13 15:46:41,485] INFO - Successfully installed BentoML-0.4.9+7.g429b9ec.dirty
#
# [2019-11-13 15:46:41,519] INFO - WARNING: You are using pip version 19.1.1, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.
#
# [2019-11-13 15:46:42,460] INFO -  ---> 863da1bf0896
#
# [2019-11-13 15:46:42,462] INFO - Step 6/10 : RUN if [ -f /container/bento/setup.sh ]; then cd /container/bento && /bin/bash -c /container/bento/setup.sh; fi
# [2019-11-13 15:46:42,465] INFO -
#
# [2019-11-13 15:46:42,606] INFO -  ---> Running in f07e5ccc4cca
#
# [2019-11-13 15:46:44,078] INFO -  ---> 75e9647c34d4
#
# [2019-11-13 15:46:44,080] INFO - Step 7/10 : ENV CLIPPER_MODEL_NAME=irisclassifier-predict-clipper
# [2019-11-13 15:46:44,082] INFO -
#
# [2019-11-13 15:46:44,204] INFO -  ---> Running in 92ae78e7e9c0
#
# [2019-11-13 15:46:44,418] INFO -  ---> 130a66e129e2
#
# [2019-11-13 15:46:44,420] INFO - Step 8/10 : ENV CLIPPER_MODEL_VERSION=20191113154121-e7d3ce
# [2019-11-13 15:46:44,422] INFO -
#
# [2019-11-13 15:46:44,534] INFO -  ---> Running in 3125a107c32e
#
# [2019-11-13 15:46:44,757] INFO -  ---> aa4d7d4583ea
#
# [2019-11-13 15:46:44,759] INFO - Step 9/10 : ENTRYPOINT []
# [2019-11-13 15:46:44,762] INFO -
#
# [2019-11-13 15:46:44,894] INFO -  ---> Running in 0d033f6b11c6
#
# [2019-11-13 15:46:45,147] INFO -  ---> cf93369bfe2f
#
# [2019-11-13 15:46:45,150] INFO - Step 10/10 : CMD ["python", "/container/clipper_entry.py"]
# [2019-11-13 15:46:45,152] INFO -
#
# [2019-11-13 15:46:45,311] INFO -  ---> Running in e7a36650bd80
#
# [2019-11-13 15:46:45,596] INFO -  ---> 8d5863be7a60
#
# [2019-11-13 15:46:45,598] INFO - Successfully built 8d5863be7a60
#
# [2019-11-13 15:46:45,604] INFO - Successfully tagged clipper-model-irisclassifier:20191113154121_E7D3CE
#
# [2019-11-13 15:46:45,606] INFO - Successfully built docker image clipper-model-irisclassifier:20191113154121_E7D3CE for Clipper deployment
# 19-11-13:15:46:45 INFO     [docker_container_manager.py:409] [default-cluster] Found 0 replicas for irisclassifier-predict-clipper:20191113154121-e7d3ce. Adding 1
# 19-11-13:15:46:46 INFO     [clipper_admin.py:724] [default-cluster] Successfully registered model irisclassifier-predict-clipper:20191113154121-e7d3ce
# 19-11-13:15:46:46 INFO     [clipper_admin.py:642] [default-cluster] Done deploying model irisclassifier-predict-clipper:20191113154121-e7d3ce.

# %% [markdown]
# List all models in your clipper cluster:

# %%
cl.get_all_models()
# Out:
# [u'irisclassifier-predict-clipper:20191113154121-e7d3ce']

# %% [markdown]
# Link this model to the bentoml-test application created above:

# %%
cl.link_model_to_app('bentoml-test', clipper_model_name)
# Out:
# 19-11-13:15:47:05 INFO     [clipper_admin.py:303] [default-cluster] Model irisclassifier-predict-clipper is now linked to application bentoml-test

# %% [markdown]
# Now you can test sending prediction request to your clipper application:

# %%
import requests, json

# Get Address
addr = cl.get_query_addr()
# Post Query
response = requests.post(
     "http://%s/%s/predict" % (addr, 'bentoml-test'),
     headers={"Content-type": "application/json"},
     data=json.dumps({
         'input': [6.5, 3.0 , 5.8, 2.2]
     }))

result = response.json()
if response.status_code == requests.codes.ok and result["default"]:
    print('A default prediction was returned.')
    print(result)

elif response.status_code != requests.codes.ok:
    print(result)
#     raise BenchmarkException(response.text)
else:
    print('Prediction Returned:', result)
# Out:
# ('Prediction Returned:', {u'default': False, u'output': 2, u'query_id': 0})
